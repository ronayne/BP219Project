# %%
import pandas as pd
import numpy as np

# %%
cytosol = pd.read_csv("subcell_location_cytosol.tsv", sep='\t')
print(cytosol)
# Out:
#         Gene                       Gene synonym          Ensembl  \
# 0       AAAS                                NaN  ENSG00000094914
# 1      AAGAB                      FLJ11506, p34  ENSG00000103591
# 2       AAK1           DKFZp686K16132, KIAA1048  ENSG00000115977
# 3      AAMDC  C11orf67, CK067, FLJ21035, PTD015  ENSG00000087884
# 4       AAMP                                NaN  ENSG00000127837
# ...      ...                                ...              ...
# 4735  ZSWIM7                               SWS1  ENSG00000214941
# 4736  ZSWIM8            4832404P21Rik, KIAA0913  ENSG00000214655
# 4737   ZUFSP                C6orf113, dJ412I7.3  ENSG00000153975
# 4738    ZW10                            KNTC1AP  ENSG00000086827
# 4739   ZWINT             KNTC2AP, SIP30, Zwint1  ENSG00000122952
#
#                                       Gene description Uniprot Chromosome  \
# 0                         Aladin WD repeat nucleoporin  Q9NRG9         12
# ...

# %%
uniprot = cytosol["Uniprot"]

# %%
print(uniprot)
# Out:
# 0       Q9NRG9
# 1       Q6PD74
# 2       Q2M2I8
# 3       Q9H7C9
# 4       Q13685
#          ...
# 4735    Q19AV6
# 4736    A7E2V4
# 4737    Q96AP4
# 4738    O43264
# 4739    O95229
# Name: Uniprot, Length: 4740, dtype: object

# %%
df = uniprot.dropna()
print(df)
# Out:
# 0       Q9NRG9
# 1       Q6PD74
# 2       Q2M2I8
# 3       Q9H7C9
# 4       Q13685
#          ...
# 4735    Q19AV6
# 4736    A7E2V4
# 4737    Q96AP4
# 4738    O43264
# 4739    O95229
# Name: Uniprot, Length: 4670, dtype: object

# %%
df.reset_index(drop=True)
# Out:
# 0       Q9NRG9
# 1       Q6PD74
# 2       Q2M2I8
# 3       Q9H7C9
# 4       Q13685
#          ...
# 4665    Q19AV6
# 4666    A7E2V4
# 4667    Q96AP4
# 4668    O43264
# 4669    O95229
# Name: Uniprot, Length: 4670, dtype: object
